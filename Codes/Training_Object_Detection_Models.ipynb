# %%
""""""""""""""
#The following code is used to train YOLO object deletction model in Google Collab

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/MyDrive/PlayerTypeDetection'  #change this accordingly

# %%
# !pip install ultralytics opencv-python-headless

import torch
import cv2
import os
from google.colab import files

from ultralytics import YOLO

# %%
# Load baseline yolo models
model = YOLO("yolo11l.pt")

# %%
"You need to change contents of config files according to your dataset source and destination path"
results = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=500, patience=30)  # train the model

# %%
"The following code is used to save the runtime models and results in Google drive, change dst_path accordingly"

import shutil

src_path = '/content/runs/detect/train'
dst_path = '/content/gdrive/MyDrive/Shot Dataset/Other/Saved Training/Detection/FinalPlayerTypeDetection'

shutil.copytree(src_path, dst_path, dirs_exist_ok=True)

# %%
"The following code is used to download run time training content"

# import shutil
# from google.colab import files

# shutil.make_archive('/content/detect', 'zip', required_path )

# files.download('/content/detect.zip')
