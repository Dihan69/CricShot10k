# %%
""""""""""""""
#The following code is used to train YOLO batter and bat segmentation model in Google Collab

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/SegmentData'  #change this accordingly

# %%
# !pip install ultralytics opencv-python-headless

import torch
import cv2
import os
from google.colab import files

from ultralytics import YOLO

# %%
# Load baseline yolo models
model = YOLO("yolo11x-seg.pt")

# %%
"You need to change contents of config files according to your dataset source and destination path"
results = model.train(data=os.path.join(ROOT_DIR, "segment_config.yaml"), epochs=500,   imgsz=224, patience=30)  # train the model

# %%
"The following code is used to save the runtime models and results in Google drive, change dst_path accordingly"

import shutil

required_path= '/content/runs/segment/train'
dst_path = '/content/gdrive/MyDrive/Shot Dataset/Other/Saved Training/Segmentation/Patience30FinalData'
shutil.copytree(required_path, dst_path, dirs_exist_ok=True)

# %%
"The following code is used to download run time training content"

# import shutil
# from google.colab import files

# shutil.make_archive('/content/segment', 'zip', required_path )

# files.download('/content/segment.zip')
